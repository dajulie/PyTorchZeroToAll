# %% [markdown]
# <a href="https://colab.research.google.com/github/dajulie/PyTorchZeroToAll/blob/main/lec_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]

w=1.0

def forward(x):
  return x * w

def loss(x, y):
  y_pred = forward(x)
  return (y_pred - y) * (y_pred - y)

w_list = []
mse_list = []
for w in np.arange(0.0, 4.1, 0.1):
  print("w= ", w)
  l_sum = 0
  for x_val, y_val in zip(x_data, y_data):
    y_pred_val = forward(x_val)
    l = loss(x_val, y_val)
    l_sum +=l
    print("\t", x_val, y_val, y_pred_val, 1)
  print("MSE= ", l_sum / 3)
  w_list.append(w)
  mse_list.append(l_sum / 3)

plt.plot(w_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('w')
plt.show()
# Out:
# w=  0.0
# 	 1.0 2.0 0.0 1
# 	 2.0 4.0 0.0 1
# 	 3.0 6.0 0.0 1
# MSE=  18.666666666666668
# w=  0.1
# 	 1.0 2.0 0.1 1
# 	 2.0 4.0 0.2 1
# 	 3.0 6.0 0.30000000000000004 1
# MSE=  16.846666666666668
# w=  0.2
# 	 1.0 2.0 0.2 1
# 	 2.0 4.0 0.4 1
# 	 3.0 6.0 0.6000000000000001 1
# MSE=  15.120000000000003
# w=  0.30000000000000004
# 	 1.0 2.0 0.30000000000000004 1
# 	 2.0 4.0 0.6000000000000001 1
# 	 3.0 6.0 0.9000000000000001 1
# MSE=  13.486666666666665
# w=  0.4
# 	 1.0 2.0 0.4 1
# 	 2.0 4.0 0.8 1
# 	 3.0 6.0 1.2000000000000002 1
# MSE=  11.946666666666667
# w=  0.5
# 	 1.0 2.0 0.5 1
# 	 2.0 4.0 1.0 1
# 	 3.0 6.0 1.5 1
# MSE=  10.5
# w=  0.6000000000000001
# 	 1.0 2.0 0.6000000000000001 1
# 	 2.0 4.0 1.2000000000000002 1
# 	 3.0 6.0 1.8000000000000003 1
# MSE=  9.146666666666663
# w=  0.7000000000000001
# 	 1.0 2.0 0.7000000000000001 1
# 	 2.0 4.0 1.4000000000000001 1
# 	 3.0 6.0 2.1 1
# MSE=  7.886666666666666
# w=  0.8
# 	 1.0 2.0 0.8 1
# 	 2.0 4.0 1.6 1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x_data = [1.0, 2.0, 3.0]
y_data = [20.0, 40.0, 60.0]

w=1.0

def forward(x):
  return x * w

def loss(x, y):
  y_pred = forward(x)
  return (y_pred - y) * (y_pred - y)

w_list = []
mse_list = []
for w in np.arange(0.0, 40.1, 0.1):
  print("w= ", w)
  l_sum = 0
  for x_val, y_val in zip(x_data, y_data):
    y_pred_val = forward(x_val)
    l = loss(x_val, y_val)
    l_sum +=l
    print("\t", x_val, y_val, y_pred_val, 1)
  print("MSE= ", l_sum / 3)
  w_list.append(w)
  mse_list.append(l_sum / 3)

plt.plot(w_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('w')
plt.show()
# Out:
# w=  0.0
# 	 1.0 20.0 0.0 1
# 	 2.0 40.0 0.0 1
# 	 3.0 60.0 0.0 1
# MSE=  1866.6666666666667
# w=  0.1
# 	 1.0 20.0 0.1 1
# 	 2.0 40.0 0.2 1
# 	 3.0 60.0 0.30000000000000004 1
# MSE=  1848.0466666666664
# w=  0.2
# 	 1.0 20.0 0.2 1
# 	 2.0 40.0 0.4 1
# 	 3.0 60.0 0.6000000000000001 1
# MSE=  1829.5199999999998
# w=  0.30000000000000004
# 	 1.0 20.0 0.30000000000000004 1
# 	 2.0 40.0 0.6000000000000001 1
# 	 3.0 60.0 0.9000000000000001 1
# MSE=  1811.0866666666668
# w=  0.4
# 	 1.0 20.0 0.4 1
# 	 2.0 40.0 0.8 1
# 	 3.0 60.0 1.2000000000000002 1
# MSE=  1792.7466666666667
# w=  0.5
# 	 1.0 20.0 0.5 1
# 	 2.0 40.0 1.0 1
# 	 3.0 60.0 1.5 1
# MSE=  1774.5
# w=  0.6000000000000001
# 	 1.0 20.0 0.6000000000000001 1
# 	 2.0 40.0 1.2000000000000002 1
# 	 3.0 60.0 1.8000000000000003 1
# MSE=  1756.3466666666666
# w=  0.7000000000000001
# 	 1.0 20.0 0.7000000000000001 1
# 	 2.0 40.0 1.4000000000000001 1
# 	 3.0 60.0 2.1 1
# MSE=  1738.2866666666666
# w=  0.8
# 	 1.0 20.0 0.8 1
# ...
